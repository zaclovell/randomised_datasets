# %% [markdown]
# # Building a randomised dataset of online digital game purchases

# %% [markdown]
# ## In this .... we will do....

# %% [markdown]
# # Before we begin, let's think about how we want the dataset to look...

# %% [markdown]
# #### We want the dataset to have 12 columns *(description of field | source)*:
#
# - **date** *(date of purchase | python random date between 01/01/2022 and 31/12/2022)*
# - **time** *(time of purchase | python random time across 24 hours)*
# - **account_id** *(account_id of account holder | python random number between 1000 and 999999)*
# - **purchase** *(title of purchased game | game_list.csv)*
# - **price** *(price of purchased game | game_list.csv)*
# - **version** *(distribution of purchased game | default setting == digital)*
# - **reg_postcode** *(registered postcode of account holder | OPENWithPANDAS_UKpostcodeslist.csv)*
# - **longitude** *(longitude of registered postcode of account holder | OPENwithPANDAS_UKpostcodeslist.csv)*
# - **latitude** *(latitude of registered postcode of account holder | OPENwithPANDAS_UKpostcodeslist.csv)*
# - **bank_no** *(sort code of account holder's bank | UKBankingSortCodes.csv)*
# - **bank_name** *(name of account holder's bank | UKBankingSortCodes.csv)*
# - **played_in_24_hours** *(True if game played within 24 hours of purchase | python random boolean)*
# - **played_in_48_hours** *(True if game not played in 24 hours but in 48 hours of purchase | python if statement)*

# %% [markdown]
# # Set up

# %%
import random
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in relevant raw data

# %%
# Game list | game_list.csv
url='https://drive.google.com/file/d/1V58XAYqIdAn0MdIE1cJxuN2ruhp0dwM_/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
gamelist = pd.read_csv(path)

# %%
# UK postcodes list | OPENwithPANDAS_UKpostcodeslist.csv
url='https://drive.google.com/file/d/1mYbtw2uqxvjEXchXmnFZnucOqanseoV5/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
UKpostcodes = pd.read_csv(path)

# %%
# Bank numbers list | UKBankingSortCodes.csv
url='https://drive.google.com/file/d/1klZZa1pVTwwnv9PwScgn0TaU3kg2W5fQ/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
banknumbers = pd.read_csv(path)

# %% [markdown]
# ##### Note: Ensure to check you have the correct raw data

# %%
#UKpostcodes.info()
#gamelist.info()
#banknumbers.info()

#UKpostcodes.head()
#gamelist.head()
banknumbers.head()
# Out:
#    GENERALSortingCode GENERALBIC1 GENERALBIC2  GENERALSubBranchSuffix  \
# 0               90025    ANILJESH         TSY                       0
# 1              239285    AIBKGB2L         XXX                       0
# 2              300083    ARAYGB22         XXX                       0
# 3              405179    ARNBGB2L         XXX                       0
# 4              300066    ARBUGB2L         AD1                       0
#
#        GENERALShortBranchTitle GENERALShortNameOwningBank  \
# 0  ABBEY NAT (OVERSEAS) W/SALE       ABBEY NAT TY INT LTD
# 1  Customer Treasury Services        AIB GB
# 2  OP HEADQUARTERS                   AL RAYAN BANK PLC
# 3  47 SEYMOUR ST LONDON W1A          ARAB NATIONAL BANK
# 4  ARBUTHNOT LATHAM & CO LTD         ARBUTHNOT LATHAM&CO
#
#         GENERALFullNameOwningBankLine1       GENERALFullNameOwningBankLine2  \
# 0  ABBEY NATIONAL TREASURY SERVICES PL  C
# 1  ALLIED IRISH BANK (GB)                                               NaN
# 2  AL RAYAN BANK PLC                                                    NaN
# 3  ARAB NATIONAL BANK                                                   NaN
# 4  ARBUTHNOT LATHAM AND CO LTD                                          NaN
#
#    GENERALBankCodeOwningBank  GENERALNationalCentralBankCountryCode  ...  \
# 0                        641                                    NaN  ...
# 1                         17                                    NaN  ...
# 2                        338                                    NaN  ...
# 3                         75                                    NaN  ...
# 4                        103                                    NaN  ...
#
#                      PRINTAddressLine3                    PRINTAddressLine4  \
# 0  Santander Hs, 19-21 Commercial St    St Helier
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#                         PRINTTown                     PRINTCounty  \
# 0  Jersey                          C.I.
# 1  London                                                     NaN
# 2  Birmingham                                                 NaN
# 3  London                                                     NaN
# 4  LONDON                                                     NaN
#
#   PRINTPostcodeField1 PRINTPostcodeField2 PRINTTelephoneArea  \
# 0                JE4                 8XG          01534
# 1                EC3A                8AB          020
# 2                B15                 1RP          0121
# 3                W1J                 7TT          020
# 4                EC2M                2SN          020
#
#   PRINTTelephoneNumber  PRINTTelephone2Area  PRINTTelephone2Number
# 0             885000.0                                         NaN
# 1           73093000.0                                         NaN
# 2            4527300.0                                         NaN
# 3           72974600.0                                         NaN
# 4           70122500.0                                         NaN
#
# [5 rows x 96 columns]

# %% [markdown]
# ##### Example: Call a column

# %%
gamelist["title"]
# Out:
# 0                                       Forspoken
# 1                              Saints Row PS4&PS5
# 2                                Ghostwire: Toyko
# 3                                WWE 2K22 for PS5
# 4                                 Ghostrunner PS5
# 5                            ELDEN RING PS4 & PS5
# 6                                  Cyberpunk 2077
# 7                                            Sifu
# 8                Dying Light 2 Stay Human PS4&PS5
# 9                 Fifa Standard Edition PS4 & PS5
# 10    Marvel's Spider-Man: Mile Morales PS4 & PS5
# 11                        Borderlands 3 PS4 & PS5
# 12       Back 4 Blood: Standard Edition PS4 & PS5
# 13                     Battlefield 2042 PS4 & PS5
# 14                   Watch Dogs: Legion PS4 & PS5
# 15               Crash Bandicoot: It's About Time
# 16                       NBA 2K21 Next Generation
# 17         Life is Strange: True Colors PS4 & PS5
# 18                Resident Evil Village PS4 & PS5
# 19                      Madden NFL 2K21 PS4 & PS5
# 20                     Rachet & Clank: Rift Apart
# 21                                      DEATHLOOP
# 22                         Horizon Forbidden West
# 23                                 Gran Turismo 7
# Name: title, dtype: object

# %% [markdown]
# ## Turn selected columns into lists ()

# %%
# from gamelist | game_list.csv
gamelist_purchase = gamelist["title"].to_list()
gamelist_price = gamelist["price"].to_list()


# from UKpostcodes | OPENwithPANDAS_UKpostcodeslist.csv

UKpostcodes_reg_postcode = UKpostcodes["Postcode"].to_list()
UKpostcodes_longitude = UKpostcodes["Latitude"].to_list()
UKpostcodes_latitude = UKpostcodes["Longitude"].to_list()


# from banknumbers | UKBankingSortCodes.csv
banknumbers_bank_no = banknumbers["GENERALSortingCode"].to_list()
banknumbers_bank_name = banknumbers["GENERALFullNameOwningBankLine1"].to_list()

# %% [markdown]
# ##### Note: You can check the data type to make sure

# %%
type(banknumbers_bank_name)
# Out:
# list

# %% [markdown]
# ### There should not be any NaNs (null values, blanks etc.) in our lists, but we should go to remove them just in case there are

# %%
# for gamelist lists
gamelist_purchase = [x for x in gamelist_purchase if pd.isnull(x) == False]
gamelist_price = [x for x in gamelist_price if pd.isnull(x) == False]


# for UKpostcodes lists

UKpostcodes_reg_postcode = [x for x in UKpostcodes_reg_postcode if pd.isnull(x) == False]
UKpostcodes_longitude = [x for x in UKpostcodes_longitude if pd.isnull(x) == False]
UKpostcodes_latitude = [x for x in UKpostcodes_latitude if pd.isnull(x) == False]


# fom banknumbers lists
banknumbers_bank_no = [x for x in banknumbers_bank_no if pd.isnull(x) == False]
banknumbers_bank_name = [x for x in banknumbers_bank_name if pd.isnull(x) == False]

# %% [markdown]
# ### Since we have prepped the raw data, we can now use the function to produce the randomised game sales dataset

# %%
def random_online_digital_game_purchases(num):
    
    '''
    function to pull a random dataset of online digital game purchases
    
    '''
    # 
    def randomTime():
        # generate random number scaled to number of seconds in a day
        # (24*60*60) = 86,400

        rtime = int(random.random()*86400)

        hours   = int(rtime/3600)
        minutes = int((rtime - hours*3600)/60)
        seconds = rtime - hours*3600 - minutes*60

        time_string = '%02d:%02d:%02d' % (hours, minutes, seconds)

        return time_string

    def rand_time_list(num):
        timelist = []
        for num in range(0,num):
            timelist.append(randomTime())
        return timelist   
    
    rand_time_randomtime = rand_time_list(num)
    
    rand_account_id = list(np.random.randint(1000, 99999, size=num))
    
    rand_gamelist_purchase = np.random.choice(gamelist_purchase, size=num)
    rand_gamelist_price = np.random.choice(gamelist_price, size=num)
    
    rand_UKpostcodes_reg_postcode = np.random.choice(UKpostcodes_reg_postcode, size=num)
    rand_UKpostcodes_longitude = np.random.choice(UKpostcodes_longitude, size=num)
    rand_UKpostcodes_latitude = np.random.choice(UKpostcodes_latitude, size=num)
    
    rand_banknumbers_bank_no = np.random.choice(banknumbers_bank_no, size=num)
    rand_banknumbers_bank_name = np.random.choice(banknumbers_bank_name, size=num)
   
    rand_played_in_24_hours = bool(random.randint(0,1))

    # Turning NoneTypes from variables above into columns of a single dataframe
    # this approach is using the dictionary method
    # {"name of column": NoneType variable, *repeat this for desired amount of columns*}
    d = {
        "date": "test",
        "time": rand_time_randomtime,
        "account_id": rand_account_id,
        "purchase": rand_gamelist_purchase,
        "price": rand_gamelist_price,
        "version": "Digital",
        "reg_postcode": rand_UKpostcodes_reg_postcode,
        "longitude": rand_UKpostcodes_longitude,
        "latitude": rand_UKpostcodes_latitude,
        "bank_no": rand_banknumbers_bank_no,
        "bank_name": rand_banknumbers_bank_name,
        "played_in_24_hours": rand_played_in_24_hours,
        "played_in_48_hours": "test",
    }

    new_dataframe = pd.DataFrame(d)
    
    
    #### thoughts
    #### certain columns needs to be consistent with the column to the left of it
    #### i.e. if X game is 29.99, the price column needs to show 29.99, not some random number
    #### a way to approach this is to cast the column which is conditional to "null" when creating
    #### the dataframe and then after the dataframe is created, run a .apply(lambda) function
    #### on the column, with an if statement that this column == the column to the left's price etc.
    #### then return the dataframe - this may work - I should try it out
    
    
    
    return new_dataframe

# %%
# Test place

def randomTime():
    # generate random number scaled to number of seconds in a day
    # (24*60*60) = 86,400
    
    rtime = int(random.random()*86400)

    hours   = int(rtime/3600)
    minutes = int((rtime - hours*3600)/60)
    seconds = rtime - hours*3600 - minutes*60

    time_string = '%02d:%02d:%02d' % (hours, minutes, seconds)
        
    return time_string


def rand_time_list(num):
    timelist = []
    for num in range(0,num):
        timelist.append(randomTime())
    return timelist

rand_time_list(10)
# Out:
# ['15:03:16',
#  '12:35:10',
#  '11:17:22',
#  '14:48:27',
#  '05:52:21',
#  '21:33:29',
#  '12:01:04',
#  '06:21:41',
#  '07:00:47',
#  '02:28:07']

# %% [markdown]
# # To Do: Focus on turning the other columns into lists like the time column, then you can start to add logic to the dataset

# %%
# Test place

import datetime

start_date = datetime.date(2020, 1, 1)
end_date = datetime.date(2020, 2, 1)

time_between_dates = end_date - start_date
days_between_dates = time_between_dates.days
random_number_of_days = random.randrange(days_between_dates)
random_date = start_date + datetime.timedelta(days=random_number_of_days)

print(random_date)
# Out:
# 2020-01-30

# %% [markdown]
# - **date** *(date of purchase | python random date between 01/01/2022 and 31/12/2022)*
# - **time** *(time of purchase | python random time across 24 hours)*
# - **account_id** *(account_id of account holder | python random number between 1000 and 999999)*
# - **purchase** *(title of purchased game | game_list.csv)*
# - **price** *(price of purchased game | game_list.csv)*
# - **version** *(distribution of purchased game | default setting == digital)*
# - **reg_postcode** *(registered postcode of account holder | OPENWithPANDAS_UKpostcodeslist.csv)*
# - **longitude** *(longitude of registered postcode of account holder | OPENwithPANDAS_UKpostcodeslist.csv)*
# - **latitude** *(latitude of registered postcode of account holder | OPENwithPANDAS_UKpostcodeslist.csv)*
# - **bank_no** *(sort code of account holder's bank | UKBankingSortCodes.csv)*
# - **bank_name** *(name of account holder's bank | UKBankingSortCodes.csv)*
# - **played_in_24_hours** *(True if game played within 24 hours of purchase | python random boolean)*
# - **played_in_48_hours** *(True if game not played in 24 hours but in 48 hours of purchase | python if statement)*

# %%
random_online_digital_game_purchases(40)
# Out:
#     date      time  account_id                                  purchase  \
# 0   test  16:58:40       34096                      ELDEN RING PS4 & PS5
# 1   test  02:21:10       63313                  NBA 2K21 Next Generation
# 2   test  19:17:47       94126                                 DEATHLOOP
# 3   test  12:11:40       12337                                      Sifu
# 4   test  04:30:40       74175                Battlefield 2042 PS4 & PS5
# 5   test  11:35:36       83642                           Ghostrunner PS5
# 6   test  15:49:54       44584                            Cyberpunk 2077
# 7   test  13:29:46       76971                                      Sifu
# 8   test  21:38:34       98668                    Horizon Forbidden West
# 9   test  00:29:10        4747                                 Forspoken
# 10  test  06:51:39       48485                          Ghostwire: Toyko
# 11  test  06:26:02       31763                                 DEATHLOOP
# 12  test  08:16:32       78580                Rachet & Clank: Rift Apart
# 13  test  07:26:54       63756                   Borderlands 3 PS4 & PS5
# 14  test  04:08:12       14734          Dying Light 2 Stay Human PS4&PS5
# 15  test  04:07:51       41564           Fifa Standard Edition PS4 & PS5
# 16  test  15:22:33       23902                                 Forspoken
# 17  test  04:39:37       61311                    Horizon Forbidden West
# 18  test  08:47:15       85952              Watch Dogs: Legion PS4 & PS5
# 19  test  13:48:26       98524                            Gran Turismo 7
# 20  test  10:12:23       49713                            Cyberpunk 2077
# 21  test  04:40:15       60828                                 Forspoken
# 22  test  10:30:48       27478          Crash Bandicoot: It's About Time
# 23  test  16:02:55       56838                                 DEATHLOOP
# 24  test  21:29:13        1494          Crash Bandicoot: It's About Time
# 25  test  18:32:53       29201                 Madden NFL 2K21 PS4 & PS5
# 26  test  19:45:52       11284    Life is Strange: True Colors PS4 & PS5
# 27  test  02:55:18       26704                          WWE 2K22 for PS5
# 28  test  09:59:45       56821          Crash Bandicoot: It's About Time
# 29  test  21:23:17       88986           Fifa Standard Edition PS4 & PS5
# 30  test  03:06:48       63289                   Borderlands 3 PS4 & PS5
# 31  test  20:24:56       85409                      ELDEN RING PS4 & PS5
# 32  test  03:15:54       95121  Back 4 Blood: Standard Edition PS4 & PS5
# 33  test  18:13:08       25492                 Madden NFL 2K21 PS4 & PS5
# 34  test  09:28:57       84598                Rachet & Clank: Rift Apart
# 35  test  14:33:51       86024                 Madden NFL 2K21 PS4 & PS5
# 36  test  14:16:33       40781           Fifa Standard Edition PS4 & PS5
# 37  test  07:38:45       40830                           Ghostrunner PS5
# 38  test  18:54:03       38435              Watch Dogs: Legion PS4 & PS5
# 39  test  10:52:13       40169          Crash Bandicoot: It's About Time
#
#     price  version reg_postcode  longitude  latitude  bank_no  \
# 0   39.99  Digital     SA15 3NP  53.755435  0.085266   609588
# 1   64.99  Digital      KT5 8YF  51.557545 -2.014062   200052
# 2   69.99  Digital      DG9 7PQ  57.507578 -2.642853   301561
# 3   64.99  Digital      MK9 1AW  54.800203 -1.150159   405056
# 4   69.99  Digital      B47 5DE  54.928015 -0.139744   165562
# 5   59.99  Digital     NE26 3SJ  53.829616 -0.158650    41300
# 6   59.99  Digital     WR14 3NT  53.555340 -0.467889   405130
# 7   59.99  Digital     NR34 9NP  53.389373 -1.772412   950001
# 8   64.99  Digital      B31 5SL  51.817366 -0.097945   300059
# 9   69.99  Digital      LD3 8SD  51.139991 -1.236641   231618
# 10  69.99  Digital     CB23 3RU  54.428713 -1.433264    41300
# 11  54.99  Digital      E17 7LH  52.677629 -3.209403    50005
# 12  24.99  Digital     CF64 1FP  51.530784 -1.852131   609591
# 13  69.99  Digital     BS22 8JS  52.395218 -0.475033   609556
# 14  39.99  Digital      SN9 5BZ  51.548582 -6.220379    86119
# 15  59.99  Digital      CR0 4DL  51.380871 -0.397000   405130
# 16  64.99  Digital      CM4 9AE  54.912673 -0.129000   159900
# 17  64.99  Digital     NR26 8UB  54.670941 -2.545642   235863
# 18  59.99  Digital      DE4 3NF  51.680108 -3.324184   405033
# 19  64.99  Digital     PO38 2AP  51.463938 -0.429867   300083
# 20  69.99  Digital     EX23 9LP  53.515173 -1.838697   405091
# 21  59.99  Digital      B91 3AA  52.175640  0.315497   231134
# 22  59.99  Digital     BH19 9BH  52.529926 -1.433354   600109
# 23  59.99  Digital     PO40 9QA  53.412318  0.249012   405111
# 24  49.99  Digital      HD9 2LR  53.281047 -0.486461    86119
# 25  59.99  Digital     CH45 5LN  53.401644 -1.850364   405179
# 26  54.99  Digital      HD5 8NW  52.198983 -0.225623   609591
# 27  59.99  Digital      CT1 1WP  50.421813 -1.386507   165221
# 28  69.99  Digital      DD4 0SR  52.992493 -3.063731   608394
# 29  69.99  Digital      RM1 3HE  50.104807 -1.185766   405059
# 30  59.99  Digital      LE5 3SN  53.050040 -2.534620   165187
# 31  59.99  Digital      GL1 2EZ  56.090508 -4.196258   230123
# 32  49.99  Digital     DN11 9QZ  54.137994 -2.260966   300173
# 33  59.99  Digital     RH20 2GN  53.652617 -0.828772   232320
# 34  39.99  Digital      BH7 6PX  51.422121 -1.672886   233504
# 35  69.99  Digital      ME7 2YW  51.188929  0.183538   300173
# 36  59.99  Digital     TN22 4JZ  51.608876 -2.217162   230123
# 37  32.99  Digital       L9 1AX  51.396143 -4.176469   405188
# 38  69.99  Digital     ME17 4UG  51.968775 -3.050772   400550
# 39  64.99  Digital     TA20 2PN  51.647317 -0.149244   405125
#
#                               bank_name  played_in_24_hours played_in_48_hours
# 0   CLEAR JUNCTION LIMITED                            False               test
# 1   Heritable Bank Limited                            False               test
# 2   SILICON VALLEY BANK                               False               test
# 3   PROJECT IMAGINE LTD                               False               test
# 4   HBL BANK UK LIMITED T/A HBL BANK UK               False               test
# 5   WEATHERBYS BANK LTD                               False               test
# 6   SAINSBURY'S BANK PLC                              False               test
# 7   BANK OF CHINA (UK) LTD                            False               test
# 8   AIB GROUP (UK) PLC (TRADING NAME FI               False               test
# 9   J P Morgan Europe Ltd                             False               test
# 10  BANK OF AMERICA, NA                               False               test
# 11  BANK OF INDIA                                     False               test
# 12  NATWEST MARKETS PLC                               False               test
# 13  STANDARD CHARTERED BANK                           False               test
# 14  SCHRODER &CO LIMITED                              False               test
# 15  CLOSE BROTHERS LIMITED                            False               test
# 16  FBN BANK UK LTD                                   False               test
# 17  IFX (UK) LTD                                      False               test
# 18  PROJECT IMAGINE LTD                               False               test
# 19  BANGKOK BANK PUBLIC COMPANY LIMITED               False               test
# 20  LEEDS BUILDING SOCIETY                            False               test
# 21  BANCO DO BRASIL SA                                False               test
# 22  THE ROYAL BANK OF SCOTLAND PLC                    False               test
# 23  THE BANK OF NEW YORK MELLON                       False               test
# 24  KBC Bank NV                                       False               test
# 25  BANK OF CEYLON (UK) LIMITED                       False               test
# 26  CITIBANK NA                                       False               test
# 27  THE NORTHERN TRUST COMPANY                        False               test
# 28  SOCIETE GENERALE                                  False               test
# 29  BNP PARIBAS SECURITIES SERVICES                   False               test
# 30  ENUMIS LIMITED                                    False               test
# 31  NEDBANK  LIMITED                                  False               test
# 32  THE ROYAL BANK OF SCOTLAND PLC                    False               test
# 33  AL RAYAN BANK PLC                                 False               test
# 34  MASHREQBANK PSC                                   False               test
# 35  DEUTSCHE BANK AG                                  False               test
# 36  ECOLOGY BUILDING SOCIETY                          False               test
# 37  DEUTSCHE BANK AG                                  False               test
# 38  NRAM LIMITED                                      False               test
# 39  BROWN, SHIPLEY & CO LTD                           False               test

# %% [markdown]
# # Saving the dataset as CSV

# %%
random_game_sales_dataset(50).to_csv("example_random_game_sales_dataset.csv", index=False)

# %%
df_saved_file = pd.read_csv("example_random_game_sales_dataset.csv")
df_saved_file.head()
# Out:
#   purchase_location game_version purchase_date
# 0               AB9      digital    12/02/2022
# 1               EF6      digital    17/02/2022
# 2              QWF6     physical    03/02/2022
# 3               EF6      digital    17/02/2022
# 4               FG8     physical    17/02/2022
